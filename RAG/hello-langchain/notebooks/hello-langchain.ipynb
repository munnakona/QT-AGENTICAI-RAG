# %%
from langchain.chat_models import init_chat_model

# %%
llm = init_chat_model(model="gemma3:270m", model_provider="ollama")
response = llm.invoke("Tell me a joke about computers.")
print(response.content)
# Out:
# Why did the computer say it was late?
# ... Because it was overloading with data!

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from dotenv import load_dotenv
import os
from langchain.chat_models import init_chat_model

load_dotenv(override=True)

MODEL = os.getenv("MODEL")
MODEL_PROVIDER = os.getenv("MODEL_PROVIDER")

print("MODEL =", MODEL)
print("MODEL_PROVIDER =", MODEL_PROVIDER)

llm = init_chat_model(model=MODEL, model_provider=MODEL_PROVIDER)

response = llm.invoke("Tell me a joke about computers.")
print(response.content)
# Out:
# MODEL = gemma3:270m
# MODEL_PROVIDER = ollama
# Why did the computer break up with the programmer?
#
# Because it was too busy with **learning how to code!**
