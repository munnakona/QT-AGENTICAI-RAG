# %%
import sys
sys.path.append("//Users/munna/VScode/QT-AgenticAI/AgenticAI/Langgraph/Langgraph_Project/")

from llm_factory import get_llm, LLMConfig

# %%
from llm_factory import get_llm, LLMConfig

config = LLMConfig(
    project="munna-genai-494015",
    location="us-central1",
    temperature=0.3
)

llm = get_llm(
    model="gemini-2.5-flash-lite",
    provider="google",
    config=config
)

# %%
response = llm.invoke("Explain LangGraph in 2 lines")
print(response.content)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# LangGraph is a Python library for building stateful, multi-agent applications by defining graphs of LLM-powered nodes and their transitions. It allows you to orchestrate complex workflows where agents can communicate, react to each other, and maintain state over time.

# %%
from langchain_core.messages import HumanMessage

result = llm.invoke([
    HumanMessage(content="What is 10 * 5?")
])

print(result.content)
# Out:
# 10 * 5 = 50
